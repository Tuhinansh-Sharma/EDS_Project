# %%
import csv
fcs=open('/content/Costumer .csv')
fcsv=open('/content/Bookings.csv')
cost=list(csv.reader(fcs,delimiter=','))
data=list(csv.reader(fcsv,delimiter=','))
data[1][1]
print(data)
print(cost)
#add=list(cost)+list(data)
#print(add)
# Out:
# [['Hamsafar', '1200', '2 Tier AC'], ['Rajdhani Express', '845', '3 Tier AC'], ['Vande Bharat', '475', 'SL'], ['Shatabdi Express', '350', 'SL'], ['Maharaja Express', '145', 'Passenger']]
# [['Sanvi', 'Pune', 'Mumbai', 'Female'], ['Mrunmayee', 'Mumbai', 'Pune', 'Female'], ['Gayatri', 'Pune', 'Nashik', 'Female'], ['Shambhavi', 'Nashik', 'Pune', 'Female'], ['Om', 'Pune', 'Nagpur', 'Male']]

# %%
cs=list.append()

# %%
#creating tuple
cs=list(cost)
t1=tuple(cs)
print(t1)

book=list(data)
t2=tuple(book)
print(t2)
# Out:
# (['Sanvi', 'Pune', 'Mumbai', 'Female'], ['Mrunmayee', 'Mumbai', 'Pune', 'Female'], ['Gayatri', 'Pune', 'Nashik', 'Female'], ['Shambhavi', 'Nashik', 'Pune', 'Female'], ['Om', 'Pune', 'Nagpur', 'Male'])
# (['Hamsafar', '1200', '2 Tier AC'], ['Rajdhani Express', '845', '3 Tier AC'], ['Vande Bharat', '475', 'SL'], ['Shatabdi Express', '350', 'SL'], ['Maharaja Express', '145', 'Passenger'])

# %%
#which passenger paid the max fare
type(data[1][1])
max=data[1][1]
range(1,len(data))
  if max>data[i][1]:
 max=data[i][1]
#print(max)
# Out:
#   File "<tokenize>", line 6
#     max=data[i][1]
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
#passenger coming or going from Nashik
#print(cost)
#print(len(cost))
# for i in range (1,len(cost));
