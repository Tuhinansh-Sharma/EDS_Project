# %%
import numpy as np
#arr=np.array([[1,2,3,4,5],[1,2,6,7,8]]);
arr=np.array([[3,2,1],[0,1,2]])
#print(arr[0,1])
#print(arr[1,3])

# %%
arr=([1,6,3,4])
max=0;
for i in range(i,len(arr)):
  if arr[i]>max :
    max=arr[i]
print(max)
# Out:
# 0
