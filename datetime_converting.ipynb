# %%
import datetime
print(datetime)
def calculateage(d):
    today=date.today()
    print('The date is',today)
    t=datetime.strptime(d,)
# Out:
# <module 'datetime' from '/usr/lib/python3.10/datetime.py'>
