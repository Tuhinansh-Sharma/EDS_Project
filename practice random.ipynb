# %%
import csv
fcsv=open('/content/Book2.csv')
data=list(csv.reader(fcsv,delimiter=','))
#print(data)

Name=[]
PRN=[]
CGPA=[]
for i in range(1,len(d1)):
  Name.append(d1[i][0])
  PRN.append(d1[i][1])
  CGPA.append(d1[i][2])
  x=max(CGPA)
  

#print(x)
#print(Name)
#print(PRN)
#print(CGPA)

# %%
sum=0
for i in range(1,len(d1)):
  sum=int(d1[i][2])
  sum=sum+d1[0][2]
return sum
print(sum)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-e19adc0ef178> in <cell line: 2>()
#       2 for i in range(1,len(d1)):
#       3   sum=int(d1[i][2])
# ----> 4   sum=sum+d1[0][2]
#       5 return sum
#       6 print(sum)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
