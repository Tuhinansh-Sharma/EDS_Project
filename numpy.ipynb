# %%
import numpy as np
arr1=np.genfromtxt("/content/employees.csv",delimiter=',',dtype=str)
#display(arr1)

# %%
employeeid=[]
employeeid=arr1[:,0]
#print(employeeid)

# %%
max(employeeid[1:])
# Out:
# '206'

# %%
min(employeeid[1:])
# Out:
# '100'

# %%
salary=[]
salary=arr1[:,7]
#print(salary)

# %%
max(salary[7:])
# Out:
# '9000'

# %%
min(salary[8:])
# Out:
# '11000'

# %%
#put argmin for min
from numpy.core.fromnumeric import argmax
argmax(employeeid[1:])
# Out:
# 8

# %%
print(arr1[9,:])
# Out:
# ['206' 'William' 'Gietz' 'WGIETZ' '515.123.8181' '07-JUN-02' 'AC_ACCOUNT'
#  '8300' ' - ' '205' '110']

# %%
j=arr1[:,6]
#print(j)

np.count_nonzero(j=="ST_CLERK")
# Out:
# 16
