# %%
import csv
fcsv=open('/content/Sales.csv')
d1=list(csv.reader(fcsv,delimiter=','))
#pructid=[]
produint(d1)
prodct_detail=[]
customer_detail=[]
Supplier_detail={}
gender={}
for i in range(len(d1)):
  productid.append(d1[i][0])
  product_detail.append(d1[i][1])
  customer_detail.append(d1[i][2])
  Supplier_detail.update({d1[i][0]:d1[i][2]})
  gender.update({d1[i][3]:d1[i][4]})

#print(productid)
#print(product_detail)
#print(customer_detail)
#print(Supplier_detail)

# %%
  frequency={}
  #product_detail
  for item in product_detail:
    if item in frequency:
      frequency[item]=frequency[item]+1
    else:
    frequency[item]=1
  #print(frequency)
  marklist=sorted(frequency.items(),key=lambda x:x[1],reverse=True)
  sortdict=dict(marklist)
  print(sortdict)
  print("The most popular product for sales",list(sortdict.keys())[0],"sold",list(sortdict.values())[0],"times")
# Out:
# {'Lenovo Laptop': 6, 'Samsung M31': 5, 'LG TV 32"': 4, 'Oppo F21': 3, 'Realmi 10pro': 2, 'Product details': 1}
# The most popular product for sales Lenovo Laptop sold 6 times

# %%
frequency={}
#iterating over the list
for item in Supplier_detail.values():
  if item in frequency:
    fre
