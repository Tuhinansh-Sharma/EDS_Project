# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes as ax
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-6384ea7894aa> in <cell line: 5>()
#       3 import matplotlib.pyplot as plt
#       4 import matplotlib.axes as ax
# ----> 5 import LinearRegression
#
# ModuleNotFoundError: No module named 'LinearRegression'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
data=pd.read_csv('/content/Tokyo 2021 dataset v4.csv')
data=data.dropna()
data.shape
# Out:
# (93, 9)

# %%
x=np.array(data['Team/NOC'])
y=np.array(data['Total'])

# %%
train_input=np.array(x[0:60]).reshape(60,1)
train_output=np.array(y[0:60]).reshape(60,1)

# %%
test_input=np.array(x[60:80]).reshape(-1,1)
test_output=np.array(y[60:80]).reshape(-1,1)

# %%
linear_reg= LinearRegression()
parameters,loss=linear_reg.train(train_input,train_output,0.0001,20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-60181b61c41d> in <cell line: 1>()
# ----> 1 linear_reg= LinearRegression()
#       2 parameters,loss=linear_reg.train(train_input,train_output,0.0001,20)
#
# NameError: name 'LinearRegression' is not defined
