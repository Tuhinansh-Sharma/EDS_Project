# %%
import numpy as np
arr= np.array([[10,20,30],[4,4,5]]);
print(arr[-1,-2])
# Out:
# 4

# %%
#slicing
import numpy as np
brr=np.array([10,20,6 0,40,50]);
#print(brr[1:4])
print(max(brr))
# Out:
# 60

# %%
x=[4]
y=[1,2]
n1=13
n2=5
#print(np.add(x,y))
#print(np.mean(x,y))
print(np.lcm(n1,n2))
# Out:
# 65

# %%
arr=[10,20,30]
brr=[5,10,60]
#print(np.add(arr,brr))
for i in range(0,3):
  crr=arr[i]+brr[i]
 # print(crr)
x=lambda arr,brr:arr-brr
print(x)
# Out:
# <function <lambda> at 0x7f9153e39090>
# 15
# 30
# 90

# %%
#split function
a=np.array_split(arr,2)
print(a)
# Out:
# [array([10, 20]), array([30])]
