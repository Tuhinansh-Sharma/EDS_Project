# %%
d={'Name':'Akash',
   'Rollno':25,
   'Div':'A'}
   
for i in d.keys():
  if i=='Age':
      print('Key exists')
      break
  else:
      print('Key does not exists')
      break
# Out:
# Key does not exists

# %% [markdown]
# d.keys()
# d.clear()
# d.pop()
# d.popitems()
# d.values()

# %%
d['result']=94
print(d)
# Out:
# {'Name': 'Akash', 'Rollno': 25, 'Div': 'A', 'result': 94}

# %%
v=d.get('result')
print(v)
# Out:
# 94
