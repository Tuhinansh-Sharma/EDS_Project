# %%
import numpy as np

arr1=np.genfromtxt("/content/employees.csv",delimiter=',',dtype=str,skip_header=1)
type(arr1)
#print(arr1[:,0])
# Out:
# numpy.ndarray

# %%
c1=arr1[:,7].astype('int32')>6000
print(type(c1))
print
# Out:
# <class 'numpy.ndarray'>
# <function print>

# %%
min(arr1[:,7].astype('int32'))
# Out:
# 2100

# %%
from numpy.core.fromnumeric import argmin
index1=argmin(arr1[:,7].astype('int32'))

# %%
print(arr1[index1:,1])
# Out:
# ['TJ' 'Jason' 'Michael' 'Ki' 'Hazel' 'Renske' 'Stephen' 'John' 'Joshua']

# %%
a=np.where(arr1[:,0].astype('int32')>200)
a
# Out:
# (array([3, 4, 5, 6, 7, 8]),)

# %%
for i in range (len(a)):
 # print(arr1[a[i],::2])
# Out:
# [['201' 'Hartstein' '515.123.5555' 'MK_MAN' ' - ' '20']
#  ['202' 'Fay' '603.123.6666' 'MK_REP' ' - ' '20']
#  ['203' 'Mavris' '515.123.7777' 'HR_REP' ' - ' '40']
#  ['204' 'Baer' '515.123.8888' 'PR_REP' ' - ' '70']
#  ['205' 'Higgins' '515.123.8080' 'AC_MGR' ' - ' '110']
#  ['206' 'Gietz' '515.123.8181' 'AC_ACCOUNT' ' - ' '110']]

# %%
c1 = data[:,3] > 37
c2=data[:,4]>4
print(c1)
print(c2)
print([c1&c2])
a=data[c1&c2]
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e31d6087b9c5> in <cell line: 1>()
# ----> 1 c1=data[:,3]>37
#       2 c2=data[:,4]>4
#       3 print(c1)
#       4 print(c2)
#       5 print([c1&c2])
#
# NameError: name 'data' is not defined

# %%
n=np.
