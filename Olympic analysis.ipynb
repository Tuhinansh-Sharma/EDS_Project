# %% [markdown]
# Olympics 2021 anaylsis
#
# Group:-
# 1.   265 Tuhinansh Sharma
# 2.   266 Tushar Najawan
# 3.    279 Atharva Pawar

# %%
import pandas as pd


df = pd.read_csv('/content/Tokyo 2021 dataset v4.csv')
df
# Out:
#     Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0      1    United States of America          39            41            33
# 1      2  People's Republic of China          38            32            18
# 2      3                       Japan          27            14            17
# 3      4               Great Britain          22            21            22
# 4      5                         ROC          20            28            23
# ..   ...                         ...         ...           ...           ...
# 88    86                       Ghana           0             0             1
# 89    86                     Grenada           0             0             1
# 90    86                      Kuwait           0             0             1
# 91    86         Republic of Moldova           0             0             1
# 92    86        Syrian Arab Republic           0             0             1
#
# ...

# %%
# 1. Display the first 5 rows
print("Query 1:")
print(df.head())
# Out:
# Query 1:
#    Rank                    Team/NOC  Gold Medal  Silver Medal  Bronze Medal  \
# 0     1    United States of America          39            41            33
# 1     2  People's Republic of China          38            32            18
# 2     3                       Japan          27            14            17
# 3     4               Great Britain          22            21            22
# 4     5                         ROC          20            28            23
#
#    Total  Rank by Total NOCCode      Continent
# 0    113              1     USA  North America
# 1     88              2     CHN           Asia
# 2     58              5     JPN           Asia
# 3     65              4     GBR         Europe
# 4     71              3     ROC    Europe/Asia

# %%
# 2. Display the last 5 rows
print("Query 2:")
print(df.tail(10))
# Out:
# Query 2:
#     Rank              Team/NOC  Gold Medal  Silver Medal  Bronze Medal  Total  \
# 83    84                Mexico           0             0             4      4
# 84    85               Finland           0             0             2      2
# 85    86              Botswana           0             0             1      1
# 86    86          Burkina Faso           0             0             1      1
# 87    86         Côte d'Ivoire           0             0             1      1
# 88    86                 Ghana           0             0             1      1
# 89    86               Grenada           0             0             1      1
# 90    86                Kuwait           0             0             1      1
# 91    86   Republic of Moldova           0             0             1      1
# 92    86  Syrian Arab Republic           0             0             1      1
#
#     Rank by Total NOCCode      Continent  Gold/Total Ratio
# ...

# %%
# 3. Display the total number of rows and columns
print("Query 3:")
print(df.shape)
# Out:
# Query 3:
# (93, 9)

# %%
# 4. Display the column names
print("Query 4:")
print(df.columns)
# Out:
# Query 4:
# Index(['Rank', 'Team/NOC', 'Gold Medal', 'Silver Medal', 'Bronze Medal',
#        'Total', 'Rank by Total', 'NOCCode', 'Continent'],
#       dtype='object')

# %%
# 5. Display the gold medal count for the United States
print("Query 5:")
print(df[df['Team/NOC'] == 'United States of America']['Gold Medal'])
# Out:
# Query 5:
# 0    39
# Name: Gold Medal, dtype: int64

# %%
# 6. Display the countries with more than 30 gold medals
print("Query 6:")
print(df[df['Gold Medal'] > 30]['Team/NOC'])
# Out:
# Query 6:
# 0      United States of America
# 1    People's Republic of China
# Name: Team/NOC, dtype: object

# %%
# 7. Display the countries in Europe
print("Query 7:")
print(df[df['Continent'] == 'Europe']['Team/NOC'])
# Out:
# Query 7:
# 3       Great Britain
# 6         Netherlands
# 7              France
# 8             Germany
# 9               Italy
# 14            Hungary
# 16             Poland
# 17     Czech Republic
# 19             Norway
# 21              Spain
# 22             Sweden
# 23        Switzerland
# 24            Denmark
# 25            Croatia
# 27             Serbia
# 28            Belgium
# 29           Bulgaria
# 30           Slovenia
# 32            Georgia
# 34             Turkey
# 35             Greece
# 38            Ireland
# 42             Kosovo
# 43            Ukraine
# 44            Belarus
# 45            Romania
# 50           Slovakia
# 52            Austria
# 56           Portugal
# 58            Estonia
# 60             Latvia
# 66         Azerbaijan
# 68            Armenia
# 72         San Marino
# 78          Lithuania
# 79    North Macedonia
# 82         Kazakhstan
# 84            Finland
# Name: Team/NOC, dtype: object

# %%
# 8. Display the top 5 countries with the highest total medal count
print("Query 8:")
print(df.nlargest(5, 'Total')[['Team/NOC', 'Total']])
# Out:
# Query 8:
#                      Team/NOC  Total
# 0    United States of America    113
# 1  People's Republic of China     88
# 4                         ROC     71
# 3               Great Britain     65
# 2                       Japan     58

# %%
#Graph for top 5 countries with the highest total medal count
import matplotlib.pyplot as plt
teams = ['USA', 'China', 'ROC', 'Great Britain', 'Japan']
medal_counts = [113, 88, 71, 65, 58]
plt.bar(teams, medal_counts)
plt.xlabel('Team/NOC')
plt.ylabel('Total Medals')
plt.title('Medal Counts by Team/NOC')
plt.show()

# %%
# 9. Display the countries with no gold medals
print("Query 9:")
print(df[df['Gold Medal'] == 0]['Team/NOC'])
# Out:
# Query 9:
# 65                Colombia
# 66              Azerbaijan
# 67      Dominican Republic
# 68                 Armenia
# 69              Kyrgyzstan
# 70                Mongolia
# 71               Argentina
# 72              San Marino
# 73                  Jordan
# 74                Malaysia
# 75                 Nigeria
# 76                 Bahrain
# 77            Saudi Arabia
# 78               Lithuania
# 79         North Macedonia
# 80                 Namibia
# 81            Turkmenistan
# 82              Kazakhstan
# 83                  Mexico
# 84                 Finland
# 85                Botswana
# 86            Burkina Faso
# 87           Côte d'Ivoire
# 88                   Ghana
# 89                 Grenada
# 90                  Kuwait
# 91     Republic of Moldova
# 92    Syrian Arab Republic
# Name: Team/NOC, dtype: object

# %%
# 10. Display the countries with more silver medals than bronze medals
print("Query 10:")
print(df[df['Silver Medal'] > df['Bronze Medal']]['Team/NOC'])
# Out:
# Query 10:
# 0       United States of America
# 1     People's Republic of China
# 4                            ROC
# 7                         France
# 17                Czech Republic
# 18                         Kenya
# 21                         Spain
# 22                        Sweden
# 25                       Croatia
# 32                       Georgia
# 37                       Ecuador
# 45                       Romania
# 46                     Venezuela
# 49                   Philippines
# 50                      Slovakia
# 51                  South Africa
# 57                       Tunisia
# 65                      Colombia
# 67            Dominican Republic
# 69                    Kyrgyzstan
# 76                       Bahrain
# 77                  Saudi Arabia
# 78                     Lithuania
# 79               North Macedonia
# 80                       Namibia
# 81                  Turkmenistan
# Name: Team/NOC, dtype: object

# %% [markdown]
# Groupby function

# %%
# 11. Display the continents and their respective total medal count
print("Query 11:")
print(df.groupby('Continent')['Total'].sum())
# Out:
# Query 11:
# Continent
# Africa            38
# Asia             237
# Australia         68
# Europe           455
# Europe/Asia       71
# North America    175
# South America     36
# Name: Total, dtype: int64

# %%
#pie chart for continents and their respective medal counts
import matplotlib.pyplot as plt
continents = ['Africa', 'Asia', 'Australia', 'Europe', 'Europe/Asia', 'North America', 'South America']
medal_counts = [38, 237, 68, 455, 71, 175, 36]
plt.pie(medal_counts, labels=continents, autopct='%1.1f%%', startangle=90)
plt.title('Medal Counts by Continent')
plt.axis('equal')
plt.show()

# %%
# 12. Display the average number of medals per country
print("Query 12:")
print(df[['Gold Medal', 'Silver Medal', 'Bronze Medal']].mean())
# Out:
# Query 12:
# Gold Medal      3.655914
# Silver Medal    3.634409
# Bronze Medal    4.322581
# dtype: float64

# %%
import matplotlib.pyplot as plt
medal_counts = [3.655914, 3.634409, 4.322581]
plt.hist(medal_counts, bins=10, edgecolor='black')
plt.xlabel('Medal Counts')
plt.ylabel('Frequency')
plt.title('Distribution of Medal Counts')
plt.show()

# %%
# 13. Display the countries with a gold medal count between 5 and 10 (inclusive)
print("Query 13:")
print(df[(df['Gold Medal'] >= 5) & (df['Gold Medal'] <= 10)]['Team/NOC'])
# Out:
# Query 13:
# 6           Netherlands
# 7                France
# 8               Germany
# 9                 Italy
# 10               Canada
# 11               Brazil
# 12          New Zealand
# 13                 Cuba
# 14              Hungary
# 15    Republic of Korea
# Name: Team/NOC, dtype: object

# %%
# 14. Display the top 3 countries with the highest silver medal count
print("Query 14:")
print(df.nlargest(3, 'Silver Medal')[['Team/NOC', 'Silver Medal']])
# Out:
# Query 14:
#                      Team/NOC  Silver Medal
# 0    United States of America            41
# 1  People's Republic of China            32
# 4                         ROC            28

# %%
#scatterplot for the top 3 countries with the highest silver medal count
import matplotlib.pyplot as plt
teams = ['United States of America', "People's Republic of China", 'ROC']
silver_medals = [41, 32, 28]
plt.scatter(teams, silver_medals, c='b', marker='o')
plt.xlabel('Team/NOC')
plt.ylabel('Silver Medals')
plt.title('Silver Medals by Team/NOC')
plt.show()

# %%
# 15. Display the countries with a total medal count of 0
print("Query 15:")
print(df[df['Total'] == 0]['Team/NOC'])
# Out:
# Query 15:
# Series([], Name: Team/NOC, dtype: object)

# %%
# 16. Display the countries with more gold medals than any other medal
print("Query 16:")
print(df[(df['Gold Medal'] > df['Silver Medal']) & (df['Gold Medal'] > df['Bronze Medal'])]['Team/NOC'])
# Out:
# Query 16:
# 1     People's Republic of China
# 2                          Japan
# 13                          Cuba
# 19                        Norway
# 26      Islamic Republic of Iran
# 29                      Bulgaria
# 30                      Slovenia
# 31                    Uzbekistan
# 35                        Greece
# 36                        Uganda
# 37                       Ecuador
# 40                         Qatar
# 41                       Bahamas
# 42                        Kosovo
# 62                       Bermuda
# 63                       Morocco
# 64                   Puerto Rico
# Name: Team/NOC, dtype: object

# %%
# 17. Display the countries with a total medal count greater than or equal to 50
print("Query 17:")
print(df[df['Total'] >= 50]['Team/NOC'])
# Out:
# Query 17:
# 0      United States of America
# 1    People's Republic of China
# 2                         Japan
# 3                 Great Britain
# 4                           ROC
# Name: Team/NOC, dtype: object

# %%
# 18. Display the countries in Asia with a bronze medal count greater than 5
print("Query 18:")
print(df[(df['Continent'] == 'Asia') & (df['Bronze Medal'] > 5)]['Team/NOC'])
# Out:
# Query 18:
# 1     People's Republic of China
# 2                          Japan
# 15             Republic of Korea
# 33                Chinese Taipei
# Name: Team/NOC, dtype: object

# %%
# 19. Display the top 5 countries with the highest gold-to-total medal ratio
print("Query 19:")
df['Gold/Total Ratio'] = df['Gold Medal'] / df['Total']
print(df.nlargest(5, 'Gold/Total Ratio')[['Team/NOC', 'Gold/Total Ratio']])
# Out:
# Query 19:
#        Team/NOC  Gold/Total Ratio
# 41      Bahamas               1.0
# 42       Kosovo               1.0
# 62      Bermuda               1.0
# 63      Morocco               1.0
# 64  Puerto Rico               1.0

# %%
#20. Total no. of gold medals
print("Query 20:")
gold_medal_count = df['Gold Medal'].count()
print("Gold Medal Count:", gold_medal_count)
# Out:
# Query 20:
# Gold Medal Count: 93
